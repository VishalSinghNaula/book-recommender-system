# %%
import os
if 'COLAB_GPU' in os.environ:
  print("GPU RUNNIG")
else:
  print("NOT")
# Out:
# GPU RUNNIG

# %%
# !pip install ultralytics==8.0.20

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/112.6 GB disk)

# %%
# %pwd
# Out:
# '/content/fireDetection/Fire-Dataset-for-YOLOv8-10'

# %%
# !mkdir fireDetection

# %%
# !ls
# Out:
# data.yaml  fireDetection  README.dataset.txt  README.roboflow.txt  runs  train	valid  yolov8n.pt

# %%
os.chdir("/content/fireDetection")
# %pwd
# Out:
# '/content/fireDetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="kTKldX11SNHsic89IWAw")
project = rf.workspace("aj-garcia-736tc").project("fire-dataset-for-yolov8")
version = project.version(10)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %ls
# Out:
# Fire-Dataset-for-YOLOv8-10/

# %%
os.chdir("/content/fireDetection/Fire-Dataset-for-YOLOv8-10")

# %%
#training
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=10 imgsz=640 batch=16
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:332: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu')  # load
# ...

# %%
# %ls '/content/fireDetection/Fire-Dataset-for-YOLOv8-10/runs/detect/train3'
# Out:
# args.yaml                                            F1_curve.png  R_curve.png  weights/
# confusion_matrix.png                                 P_curve.png   results.csv
# events.out.tfevents.1736512075.0417a88124a3.12054.0  PR_curve.png  results.png

# %%
#display
resultData = "/content/fireDetection/Fire-Dataset-for-YOLOv8-10/runs/detect/train3/"
from IPython.display import Image, display
Image(filename = f'{resultData}confusion_matrix.png')

# %%
Image(filename = f'{resultData}results.png')

# %%
import pandas as pd

df = pd.read_csv(f'{resultData}results.csv')
print(df.head(5))
# Out:
#                   epoch        train/box_loss        train/cls_loss  \
# 0                     0                1.7952                3.0311
# 1                     1                1.6821                1.9301
# 2                     2                1.7167                1.7937
# 3                     3                1.7312                1.7683
# 4                     4                1.6914                1.6375
#
#          train/dfl_loss  metrics/precision(B)  ...          val/cls_loss  \
# 0                1.6200               0.45418  ...                2.6984
# 1                1.4975               0.38498  ...                2.4507
# 2                1.5260               0.20402  ...                2.8070
# 3                1.5523               0.59284  ...                2.0278
# 4                1.5164               0.44797  ...                2.0711
#
#            val/dfl_loss                lr/pg0                lr/pg1  \
# ...

# %%
print(df.tail(1))
# Out:
#                   epoch        train/box_loss        train/cls_loss  \
# 9                     9                1.4084                 1.177
#
#          train/dfl_loss  metrics/precision(B)  ...          val/cls_loss  \
# 9                1.3217               0.42481  ...                1.8833
#
#            val/dfl_loss                lr/pg0                lr/pg1  \
# 9                1.5734               0.00208               0.00208
#
#                  lr/pg2
# 9               0.00208
#
# [1 rows x 14 columns]

# %%
# %pwd
# Out:
# '/content/fireDetection/Fire-Dataset-for-YOLOv8-10'

# %%
os.chdir("/content")

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir TestingData

# %%
# %pwd
# Out:
# '/content'

# %%
os.chdir("/content/TestingData")

# %%
# %pwd
# Out:
# '/content/TestingData'

# %%
url1 = "https://drive.google.com/file/d/1AmzwDclqLrCTVZlFDfJDFIyzZTl5L2Wr/view?usp=sharing"
id = "1AmzwDclqLrCTVZlFDfJDFIyzZTl5L2Wr"

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1AmzwDclqLrCTVZlFDfJDFIyzZTl5L2Wr' -O inputFire1.mp4
# Out:
# --2025-01-10 12:48:04--  https://docs.google.com/uc?export=download&id=1AmzwDclqLrCTVZlFDfJDFIyzZTl5L2Wr
# Resolving docs.google.com (docs.google.com)... 74.125.200.138, 74.125.200.101, 74.125.200.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.200.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1AmzwDclqLrCTVZlFDfJDFIyzZTl5L2Wr&export=download [following]
# --2025-01-10 12:48:04--  https://drive.usercontent.google.com/download?id=1AmzwDclqLrCTVZlFDfJDFIyzZTl5L2Wr&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.200.132, 2404:6800:4003:c1a::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.200.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3363588 (3.2M) [video/mp4]
# Saving to: ‘inputFire1.mp4’
#
# ...

# %%
url2 = "https://drive.google.com/file/d/1D2Nl4TL4_8gqMlB5IMaRvmClUc8RKiTQ/view?usp=sharing"
id = "1D2Nl4TL4_8gqMlB5IMaRvmClUc8RKiTQ"

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1D2Nl4TL4_8gqMlB5IMaRvmClUc8RKiTQ' -O inputFire2.mp4
# Out:
# --2025-01-10 12:48:19--  https://docs.google.com/uc?export=download&id=1D2Nl4TL4_8gqMlB5IMaRvmClUc8RKiTQ
# Resolving docs.google.com (docs.google.com)... 74.125.200.138, 74.125.200.101, 74.125.200.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.200.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1D2Nl4TL4_8gqMlB5IMaRvmClUc8RKiTQ&export=download [following]
# --2025-01-10 12:48:19--  https://drive.usercontent.google.com/download?id=1D2Nl4TL4_8gqMlB5IMaRvmClUc8RKiTQ&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.200.132, 2404:6800:4003:c1a::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.200.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1099262 (1.0M) [video/mp4]
# Saving to: ‘inputFire2.mp4’
#
# ...

# %%
weightsPath1 = "/content/fireDetection/Fire-Dataset-for-YOLOv8-10/runs/detect/train3/weights"
# !yolo task=detect mode=predict model={weightsPath1}/best.pt conf=.25 source='inputFire1.mp4' save = True
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:332: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu')  # load
# ...

# %%
weightsPath2 = "/content/fireDetection/Fire-Dataset-for-YOLOv8-10/runs/detect/train2/weights"
# !yolo task=detect mode=predict model={weightsPath2}/best.pt conf=.25 source='inputFire2.mp4' save = True
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:332: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu')  # load
# ...

# %%
from google.colab import files
files.download('/content/TestingData/runs/detect/predict/inputFire1.mp4')
files.download('/content/TestingData/runs/detect/predict2/inputFire2.mp4')
